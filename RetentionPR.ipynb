# %% [markdown]
# <a href="https://colab.research.google.com/github/NerdDESTROYER/RetentionPR/blob/main/RetentionPR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q hvplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot
import hvplot.pandas

# %matplotlib inline
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c5e2143c-a2c4-42ca-840a-9737e420013e" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import os

new_var = r"/content/WA_Fn-UseC_-HR-Employee-Attrition.csv"

file_path = new_var
print(os.path.exists(file_path))
# Out:
# True

# %%
file_path = r"/content/WA_Fn-UseC_-HR-Employee-Attrition.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
for column in df.columns:
    print(f"{column}: {df[column].nunique()}")
# Out:
# Age: 43
# Attrition: 2
# BusinessTravel: 3
# DailyRate: 886
# Department: 3
# DistanceFromHome: 29
# Education: 5
# EducationField: 6
# EmployeeCount: 1
# EmployeeNumber: 1470
# EnvironmentSatisfaction: 4
# Gender: 2
# HourlyRate: 71
# JobInvolvement: 4
# JobLevel: 5
# JobRole: 9
# JobSatisfaction: 4
# MaritalStatus: 3
# MonthlyIncome: 1349
# MonthlyRate: 1427
# NumCompaniesWorked: 10
# Over18: 1
# OverTime: 2
# PercentSalaryHike: 15
# PerformanceRating: 2
# RelationshipSatisfaction: 4
# StandardHours: 1
# StockOptionLevel: 4
# TotalWorkingYears: 40
# TrainingTimesLastYear: 7
# WorkLifeBalance: 4
# YearsAtCompany: 37
# YearsInCurrentRole: 19
# YearsSinceLastPromotion: 16
# YearsWithCurrManager: 18

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 31)

# %%
#Checking for missing values...
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %% [markdown]
# NO missing values are there in the dataset, can move on to the next step

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
categorical_columns =[column for column in df.columns if df[column].dtype == "object"]

# %%
categorical_columns
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
less25_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() < 25:
        print(f"{column}")
        less25_col.append(column)
# Out:
# Education
# EnvironmentSatisfaction
# JobInvolvement
# JobLevel
# JobSatisfaction
# NumCompaniesWorked
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StockOptionLevel
# TrainingTimesLastYear
# WorkLifeBalance
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
less25_col
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
u25_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() > 25:
        print(f"{column} : Minimum: {df[column].min()}, Maximum: {df[column].max()}")
        u25_col.append(column)
# Out:
# Age : Minimum: 18, Maximum: 60
# DailyRate : Minimum: 102, Maximum: 1499
# DistanceFromHome : Minimum: 1, Maximum: 29
# HourlyRate : Minimum: 30, Maximum: 100
# MonthlyIncome : Minimum: 1009, Maximum: 19999
# MonthlyRate : Minimum: 2094, Maximum: 26999
# TotalWorkingYears : Minimum: 0, Maximum: 40
# YearsAtCompany : Minimum: 0, Maximum: 40

# %%
df.shape
# Out:
# (1470, 31)

# %%
#Converting categorial features of YES/NO of o/p to the 1/0 form

from sklearn.preprocessing import LabelEncoder

output_Data = LabelEncoder()
df["Attrition"] = output_Data.fit_transform(df.Attrition)

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
#Age
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Age', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION
#Age 30-40 quits the most

# %%
df['Age'].value_counts()
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
#DailyRate
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='DailyRate', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#Distance From Home
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='DistanceFromHome', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#Education
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Education', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#EnvironmentSatisfaction
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='EnvironmentSatisfaction', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION :: Yes/No is evenly distributed for any unique value

# %%
#HourlyRate
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='HourlyRate', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#JobInvolvement
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='JobInvolvement', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : 3.0 people quit their job more than anyone

# %%
#JobLevel
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='JobLevel', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION  : Almost everyone in 4.0/5.0 quit their jobs...

# %%
#JobSatisfaction
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='JobSatisfaction', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION. There is no big gap for any particular rating value

# %%
#MonthlyIncome
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='MonthlyIncome', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION: Everyone in 14000-18900 quit their jobs

# %%
#MonthlyRate
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='MonthlyRate', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#NumCompaniesWorked
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='NumCompaniesWorked', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#PercentSalaryHike
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='PercentSalaryHike', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : highest drop-out is from lower percentage category

# %%
#PerformanceRating
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='PerformanceRating', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : Data is evenly distributed btw yes/no

# %%
#RelationshipSatisfaction
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='RelationshipSatisfaction', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : Dats is evenly distributed btw yes/nO

# %%
#StockOptionLevel
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='StockOptionLevel', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : People other than 0.0 are more likely to quit

# %%
#TotalWorkingYears
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='TotalWorkingYears', hue='Attrition', bins=30, element='step')
plt.show()

  #OBSERVATION :  Almost everyone is likely to quit after >7 yrs

# %%
#TrainingTimesLastYear
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='TrainingTimesLastYear', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#WorkLifeBalance
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='WorkLifeBalance', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATOIN : People other than 1.0 are more equally distributed in other 3 categories btw yes/no

# %%
#YearsAtCompany
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='YearsAtCompany', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#YearsInCurrentRole
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='YearsInCurrentRole', hue='Attrition', bins=30, element='step')
plt.show()

#OBSERVATION : Almost everyone >10 are likely to quit their jobs

# %%
#YearsSinceLastPromotion
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='YearsSinceLastPromotion', hue='Attrition', bins=30, element='step')
plt.show()

# %%
#YearsWithCurrManager
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='YearsWithCurrManager', hue='Attrition', bins=30, element='step')
plt.show()

# %%
df.drop(['PerformanceRating', 'RelationshipSatisfaction', 'EnvironmentSatisfaction'], axis="columns", inplace=True)

# %%
df.shape

#DONE WITH HISTOGRAMS FOR THE NUMERICAL FEATURES...
# Out:
# (1470, 28)

# %%
#BUSINESS-TRAVEL

plt.figure(figsize=(10, 6))
sns.countplot(y='BusinessTravel', hue='Attrition', data=df)
plt.show()

#OBSERVATION :  Who do not travel, are more likely to quit- in ratio wise aspect

# %%
#Department
plt.figure(figsize=(10, 6))
sns.countplot(y='Department', hue='Attrition', data=df)
plt.show()

# %%
#EducationField
plt.figure(figsize=(10, 6))
sns.countplot(y='EducationField', hue='Attrition', data=df)
plt.show()

#OBESRVATION : Life sciences people are more likely to quit their jobs

# %%
#Gender
plt.figure(figsize=(10, 6))
sns.countplot(y='Gender', hue='Attrition', data=df)
plt.show()

#Male are more likely to quit their jobs

# %%
#JobRole
plt.figure(figsize=(10, 6))
sns.countplot(y='JobRole', hue='Attrition', data=df)
plt.show()

#RD , Manager , Healthcare Representation are more likely to quit their jobs

# %%
#MaritalStatus
plt.figure(figsize=(10, 6))
sns.countplot(y='MaritalStatus', hue='Attrition', data=df)
plt.show()

#People who are single likely to stay than others in term of ratio aspect

# %%
#OverTime
plt.figure(figsize=(10, 6))
sns.countplot(y='OverTime', hue='Attrition', data=df)
plt.show()

# %%
df.shape

#Done with categorial features and their visualization
# Out:
# (1470, 28)

# %%
#Done with the plotting parts..

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()
enc.fit(df[["BusinessTravel","Department", "EducationField", "Gender", "JobRole", "MaritalStatus",  "OverTime"]])
# Out:
# OrdinalEncoder()

# %%
df[["BusinessTravel","Department", "EducationField", "Gender", "JobRole", "MaritalStatus",  "OverTime"]] = enc.transform(df[["BusinessTravel","Department", "EducationField", "Gender", "JobRole", "MaritalStatus",  "OverTime"]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   BusinessTravel           1470 non-null   float64
#  3   DailyRate                1470 non-null   int64
#  4   Department               1470 non-null   float64
#  5   DistanceFromHome         1470 non-null   int64
#  6   Education                1470 non-null   int64
#  7   EducationField           1470 non-null   float64
#  8   Gender                   1470 non-null   float64
#  9   HourlyRate               1470 non-null   int64
#  10  JobInvolvement           1470 non-null   int64
#  11  JobLevel                 1470 non-null   int64
#  12  JobRole                  1470 non-null   float64
#  13  JobSatisfaction          1470 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=["Attrition"]), df["Attrition"], test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (1176, 27)

# %%
plt.figure(figsize=(19,13))
cor=X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if ((corr_matrix.iloc[i, j] >= threshold)):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)

    return col_corr

# %%
corr_features=correlation(X_train, 0.7)

# %%
corr_features
# Out:
# {'MonthlyIncome',
#  'TotalWorkingYears',
#  'YearsInCurrentRole',
#  'YearsWithCurrManager'}

# %%
X_train.drop(corr_features, axis=1, inplace=True)
X_test.drop(corr_features, axis=1, inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1176 entries, 1374 to 684
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1176 non-null   int64
#  1   BusinessTravel           1176 non-null   float64
#  2   DailyRate                1176 non-null   int64
#  3   Department               1176 non-null   float64
#  4   DistanceFromHome         1176 non-null   int64
#  5   Education                1176 non-null   int64
#  6   EducationField           1176 non-null   float64
#  7   Gender                   1176 non-null   float64
#  8   HourlyRate               1176 non-null   int64
#  9   JobInvolvement           1176 non-null   int64
#  10  JobLevel                 1176 non-null   int64
#  11  JobRole                  1176 non-null   float64
#  12  JobSatisfaction          1176 non-null   int64
#  13  MaritalStatus            1176 non-null   float64
# ...

# %%
X_train.shape
# Out:
# (1176, 23)

# %%
#Done correlation and removed the 1/2 feature that are highely co-related

# %%
df.drop(corr_features, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   BusinessTravel           1470 non-null   float64
#  3   DailyRate                1470 non-null   int64
#  4   Department               1470 non-null   float64
#  5   DistanceFromHome         1470 non-null   int64
#  6   Education                1470 non-null   int64
#  7   EducationField           1470 non-null   float64
#  8   Gender                   1470 non-null   float64
#  9   HourlyRate               1470 non-null   int64
#  10  JobInvolvement           1470 non-null   int64
#  11  JobLevel                 1470 non-null   int64
#  12  JobRole                  1470 non-null   float64
#  13  JobSatisfaction          1470 non-null   int64
# ...

# %%
X_train['Age'].skew()
#SKEW
# Out:
# 0.41134031160231466

# %%
percentile25 = X_train['Age'].quantile(0.25)
percentile75 = X_train['Age'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
# Out:
# 12.25

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 60.625
# 11.625

# %%
X_train[(X_train['Age']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['Age']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train['BusinessTravel'].skew()
#SKEW
# Out:
# -1.4122068197671584

# %%
percentile25 = X_train['BusinessTravel'].quantile(0.25)
percentile75 = X_train['BusinessTravel'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
# Out:
# 1.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 3.5
# -0.5

# %%
X_train[(X_train['BusinessTravel']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['BusinessTravel']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['DailyRate'].skew())
#NORMAL
print(X_train['DailyRate'].mean()+3*X_train['DailyRate'].std())
print(X_train['DailyRate'].mean()-3*X_train['DailyRate'].std())
# Out:
# -0.021651999698556166
# 2019.8733509990307
# -415.8070244684185

# %%
X_train[(X_train['DailyRate']>2019.8733509990307) | (X_train['DailyRate']<-415.8070244684185)]

#OBSERVATION: No outlier present in this feature
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['Department'].skew())
#SKEW

X_train['Department'].describe()
# Out:
# 0.16810924986285525
# count    1176.000000
# mean        1.253401
# std         0.528737
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: Department, dtype: float64

# %%
percentile25 = X_train['Department'].quantile(0.25)
percentile75 = X_train['Department'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
# Out:
# 1.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 3.5
# -0.5

# %%
X_train[(X_train['Department']>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['Department']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['DistanceFromHome'].skew())
#SKEW
X_train['DistanceFromHome'].describe()
# Out:
# 0.9654135068735658
# count    1176.000000
# mean        9.159864
# std         8.137224
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
percentile25 = X_train['DistanceFromHome'].quantile(0.25)
percentile75 = X_train['DistanceFromHome'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
# Out:
# 12.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 32.0
# -16.0

# %%
X_train[(X_train['DistanceFromHome']>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['DistanceFromHome']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['Education'].skew())
#SKEW

X_train['Education'].describe()
# Out:
# -0.29302497384126897
# count    1176.000000
# mean        2.918367
# std         1.009809
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Education, dtype: float64

# %%
percentile25 = X_train['Education'].quantile(0.25)
percentile75 = X_train['Education'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2.0
# 7.0
# -1.0

# %%
X_train[(X_train['Education']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['Education']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['EducationField'].skew())
#SKEW

X_train['EducationField'].describe()
# Out:
# 0.5647642049020096
# count    1176.000000
# mean        2.235544
# std         1.334247
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: EducationField, dtype: float64

# %%
percentile25 = X_train['EducationField'].quantile(0.25)
percentile75 = X_train['EducationField'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 6.0
# -2.0

# %%
X_train[(X_train['EducationField']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['EducationField']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['Gender'].skew())
#SKEW

X_train['Gender'].describe()
# Out:
# -0.43567159485496454
# count    1176.000000
# mean        0.606293
# std         0.488779
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Gender, dtype: float64

# %%
percentile25 = X_train['Gender'].quantile(0.25)
percentile75 = X_train['Gender'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 2.5
# -1.5

# %%
X_train[(X_train['Gender']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['Gender']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['HourlyRate'].skew())
#NORMAL

print(X_train['HourlyRate'].mean()+3*X_train['HourlyRate'].std())
print(X_train['HourlyRate'].mean()-3*X_train['HourlyRate'].std())
# Out:
# 0.005823852880639039
# 126.01307908023847
# 4.247125001394181

# %%
X_train[(X_train['HourlyRate']>126.01307908023847) | (X_train['HourlyRate']<4.247125001394181)]

#OBSERVATION: No outlier present in this feature
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['JobInvolvement'].skew())
#SKEW

X_train['JobInvolvement'].describe()
# Out:
# -0.4777883146358142
# count    1176.000000
# mean        2.724490
# std         0.715027
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: JobInvolvement, dtype: float64

# %%
percentile25 = X_train['JobInvolvement'].quantile(0.25)
percentile75 = X_train['JobInvolvement'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 4.5
# 0.5

# %%
X_train[(X_train['JobInvolvement']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['JobInvolvement']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['JobLevel'].skew())
#SKEW

X_train['JobLevel'].describe()
# Out:
# 1.0209996170014477
# count    1176.000000
# mean        2.055272
# std         1.106040
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: JobLevel, dtype: float64

# %%
percentile25 = X_train['JobLevel'].quantile(0.25)
percentile75 = X_train['JobLevel'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2.0
# 6.0
# -2.0

# %%
X_train[(X_train['JobLevel']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['JobLevel']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['JobRole'].skew())
#SKEW

X_train['JobRole'].describe()
# Out:
# -0.35943620093974993
# count    1176.000000
# mean        4.475340
# std         2.442755
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: JobRole, dtype: float64

# %%
percentile25 = X_train['JobRole'].quantile(0.25)
percentile75 = X_train['JobRole'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 5.0
# 14.5
# -5.5

# %%
X_train[(X_train['JobRole']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['JobRole']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['JobSatisfaction'].skew())
#SKEW

X_train['JobSatisfaction'].describe()
# Out:
# -0.328042555772975
# count    1176.000000
# mean        2.732993
# std         1.102477
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
percentile25 = X_train['JobSatisfaction'].quantile(0.25)
percentile75 = X_train['JobSatisfaction'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2.0
# 7.0
# -1.0

# %%
X_train[(X_train['JobSatisfaction']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['JobSatisfaction']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['MaritalStatus'].skew())
#SKEW

X_train['MaritalStatus'].describe()
# Out:
# -0.16358812690241903
# count    1176.000000
# mean        1.102041
# std         0.737884
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: MaritalStatus, dtype: float64

# %%
percentile25 = X_train['MaritalStatus'].quantile(0.25)
percentile75 = X_train['MaritalStatus'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 3.5
# -0.5

# %%
X_train[(X_train['MaritalStatus']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['MaritalStatus']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['MonthlyRate'].skew())
#NORMAL

print(X_train['MonthlyRate'].mean()+3*X_train['MonthlyRate'].std())
print(X_train['MonthlyRate'].mean()-3*X_train['MonthlyRate'].std())
# Out:
# 0.02063487887688983
# 35648.462361025006
# -7154.142633133846

# %%
X_train[(X_train['MonthlyRate']>35648.462361025006) | (X_train['MonthlyRate']<-7154.142633133846)]

#OBSERVATION: No outlier present in this feature
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['NumCompaniesWorked'].skew())
#SKEW

X_train['NumCompaniesWorked'].describe()
# Out:
# 1.0146359575361223
# count    1176.000000
# mean        2.703231
# std         2.521301
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         9.000000
# Name: NumCompaniesWorked, dtype: float64

# %%
percentile25 = X_train['NumCompaniesWorked'].quantile(0.25)
percentile75 = X_train['NumCompaniesWorked'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 3.0
# 8.5
# -3.5

# %%
X_train[(X_train['NumCompaniesWorked']>upper_limit) ]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 440    34             1.0        988         0.0                23          3
# 597    42             2.0        932         1.0                 1          2
# 401    56             1.0        906         2.0                 6          3
# 194    45             0.0       1195         1.0                 2          2
# 789    44             2.0       1376         0.0                 1          2
# 371    29             2.0       1283         1.0                23          3
# 927    36             2.0        429         1.0                 2          4
# 541    36             0.0        427         1.0                 8          3
# 1357   42             2.0       1396         1.0                 6          3
# 1145   36             2.0        559         1.0                12          4
# 95     54             2.0       1217         1.0                 2          4
# ...

# %%
X_train_new = X_train.copy()
X_train_new['NumCompaniesWorked'] = np.where(X_train_new['NumCompaniesWorked'] > upper_limit, upper_limit, X_train_new['NumCompaniesWorked'])
X_train = X_train_new

# %%
X_train.shape
# Out:
# (1176, 23)

# %%
X_train[(X_train['NumCompaniesWorked']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['OverTime'].skew())
#SKEW

X_train['OverTime'].describe()
# Out:
# 1.0110079953037452
# count    1176.000000
# mean        0.274660
# std         0.446533
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: OverTime, dtype: float64

# %%
percentile25 = X_train['OverTime'].quantile(0.25)
percentile75 = X_train['OverTime'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 2.5
# -1.5

# %%
X_train[(X_train['OverTime']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['OverTime']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['PercentSalaryHike'].skew())
#SKEW

X_train['PercentSalaryHike'].describe()
# Out:
# 0.8471247569914732
# count    1176.000000
# mean       15.152211
# std         3.652543
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64

# %%
percentile25 = X_train['PercentSalaryHike'].quantile(0.25)
percentile75 = X_train['PercentSalaryHike'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 6.0
# 27.0
# 3.0

# %%
X_train[(X_train['PercentSalaryHike']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['PercentSalaryHike']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['StockOptionLevel'].skew())
#SKEW

X_train['StockOptionLevel'].describe()
# Out:
# 0.9621561671881281
# count    1176.000000
# mean        0.805272
# std         0.865611
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: StockOptionLevel, dtype: float64

# %%
percentile25 = X_train['StockOptionLevel'].quantile(0.25)
percentile75 = X_train['StockOptionLevel'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 2.5
# -1.5

# %%
X_train[(X_train['StockOptionLevel']>upper_limit) ]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1224   26             2.0        390         1.0                17          4
# 440    34             1.0        988         0.0                23          3
# 92     30             2.0       1334         2.0                 4          2
# 977    34             0.0        999         1.0                26          1
# 1264   55             2.0        478         1.0                 2          3
# ...   ...             ...        ...         ...               ...        ...
# 868    28             2.0       1179         1.0                19          4
# 779    51             2.0       1323         1.0                 4          4
# 335    40             2.0       1124         2.0                 1          2
# 1289   38             0.0       1336         0.0                 2          3
# 850    32             0.0        862         2.0                 2          1
#
# ...

# %%
X_train_new = X_train.copy()
X_train_new['StockOptionLevel'] = np.where(X_train_new['StockOptionLevel'] > upper_limit, upper_limit, X_train_new['StockOptionLevel'])
X_train = X_train_new

# %%
X_train[(X_train['StockOptionLevel']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['TrainingTimesLastYear'].skew())
#SKEW

X_train['TrainingTimesLastYear'].describe()
# Out:
# 0.5436220780554715
# count    1176.000000
# mean        2.767007
# std         1.250756
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         6.000000
# Name: TrainingTimesLastYear, dtype: float64

# %%
percentile25 = X_train['TrainingTimesLastYear'].quantile(0.25)
percentile75 = X_train['TrainingTimesLastYear'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 4.5
# 0.5

# %%
X_train[(X_train['TrainingTimesLastYear']>upper_limit) ]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 519    29             1.0        806         1.0                 1          4
# 427    60             1.0       1499         2.0                28          3
# 434    31             2.0       1274         1.0                 9          1
# 1350   27             2.0        511         2.0                 2          2
# 563    25             2.0        883         2.0                26          1
# ...   ...             ...        ...         ...               ...        ...
# 273    37             2.0        228         2.0                 6          4
# 543    44             0.0        381         1.0                24          3
# 697    29             1.0       1404         2.0                20          3
# 777    21             2.0       1334         1.0                10          3
# 1094   40             2.0       1342         2.0                 9          2
#
# ...

# %%
X_train_new = X_train.copy()
X_train_new['TrainingTimesLastYear'] = np.where(X_train_new['TrainingTimesLastYear'] > upper_limit, upper_limit, X_train_new['TrainingTimesLastYear'])
X_train = X_train_new

# %%
X_train[(X_train['TrainingTimesLastYear']<lower_limit)]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1169   27             2.0        486         1.0                 8          3
# 512    27             2.0       1115         1.0                 3          4
# 401    56             1.0        906         2.0                 6          3
# 1044   49             2.0       1495         1.0                 5          4
# 828    18             0.0        247         1.0                 8          1
# 1133   43             2.0        990         1.0                27          3
# 817    36             0.0        217         1.0                18          4
# 984    28             2.0        736         2.0                26          3
# 261    38             0.0       1327         2.0                 2          2
# 798    33             2.0       1017         1.0                25          3
# 1369   28             2.0       1475         2.0                13          2
# ...

# %%
X_train_new = X_train.copy()
X_train_new['TrainingTimesLastYear'] = np.where(X_train_new['TrainingTimesLastYear'] < lower_limit, lower_limit, X_train_new['TrainingTimesLastYear'])
X_train = X_train_new

# %%
print(X_train['WorkLifeBalance'].skew())
#SKEW

X_train['WorkLifeBalance'].describe()
# Out:
# -0.5667894922352439
# count    1176.000000
# mean        2.764456
# std         0.713251
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: WorkLifeBalance, dtype: float64

# %%
percentile25 = X_train['WorkLifeBalance'].quantile(0.25)
percentile75 = X_train['WorkLifeBalance'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 1.0
# 4.5
# 0.5

# %%
X_train[(X_train['WorkLifeBalance']>upper_limit) ]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train[(X_train['WorkLifeBalance']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['YearsAtCompany'].skew())
#SKEW

X_train['YearsAtCompany'].describe()
# Out:
# 1.755857355488084
# count    1176.000000
# mean        6.982143
# std         6.094338
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
percentile25 = X_train['YearsAtCompany'].quantile(0.25)
percentile75 = X_train['YearsAtCompany'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 6.0
# 18.0
# -6.0

# %%
X_train[(X_train['YearsAtCompany']>upper_limit) ]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1303   47             2.0       1001         1.0                 4          3
# 186    40             2.0        989         1.0                 4          1
# 411    60             2.0        422         1.0                 7          3
# 922    44             2.0       1199         1.0                 4          2
# 251    39             1.0        505         1.0                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 544    47             1.0        217         2.0                 3          3
# 1445   41             2.0        582         1.0                28          4
# 448    40             2.0        302         1.0                 6          3
# 976    56             2.0       1369         1.0                23          3
# 314    39             2.0        117         1.0                10          1
#
# ...

# %%
X_train_new = X_train.copy()
X_train_new['YearsAtCompany'] = np.where(X_train_new['YearsAtCompany'] > upper_limit, upper_limit, X_train_new['YearsAtCompany'])
X_train = X_train_new

# %%
X_train[(X_train['YearsAtCompany']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(X_train['YearsSinceLastPromotion'].skew())
#SKEW

X_train['YearsSinceLastPromotion'].describe()
# Out:
# 1.9911217401529289
# count    1176.000000
# mean        2.160714
# std         3.208052
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.250000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
percentile25 = X_train['YearsSinceLastPromotion'].quantile(0.25)
percentile75 = X_train['YearsSinceLastPromotion'].quantile(0.75)
iqr = percentile75 - percentile25
print(iqr)
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 2.25
# 5.625
# -3.375

# %%
X_train[(X_train['YearsSinceLastPromotion']>upper_limit) ]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 768    40             2.0        300         2.0                26          3
# 1303   47             2.0       1001         1.0                 4          3
# 61     38             1.0        653         1.0                29          5
# 186    40             2.0        989         1.0                 4          1
# 997    27             2.0        135         1.0                17          4
# ...   ...             ...        ...         ...               ...        ...
# 314    39             2.0        117         1.0                10          1
# 600    32             2.0        859         1.0                 4          3
# 1094   40             2.0       1342         2.0                 9          2
# 277    38             2.0        322         2.0                 7          2
# 1216   43             2.0       1179         2.0                 2          3
#
# ...

# %%
X_train_new = X_train.copy()
X_train_new['YearsSinceLastPromotion'] = np.where(X_train_new['YearsSinceLastPromotion'] > upper_limit, upper_limit, X_train_new['YearsSinceLastPromotion'])
X_train = X_train_new

# %%
X_train[(X_train['YearsSinceLastPromotion']<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, StockOptionLevel, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsSinceLastPromotion]
# Index: []
#
# [0 rows x 23 columns]

# %%
X_train.shape
# Out:
# (1176, 23)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1176 entries, 1374 to 684
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1176 non-null   int64
#  1   BusinessTravel           1176 non-null   float64
#  2   DailyRate                1176 non-null   int64
#  3   Department               1176 non-null   float64
#  4   DistanceFromHome         1176 non-null   int64
#  5   Education                1176 non-null   int64
#  6   EducationField           1176 non-null   float64
#  7   Gender                   1176 non-null   float64
#  8   HourlyRate               1176 non-null   int64
#  9   JobInvolvement           1176 non-null   int64
#  10  JobLevel                 1176 non-null   int64
#  11  JobRole                  1176 non-null   float64
#  12  JobSatisfaction          1176 non-null   int64
#  13  MaritalStatus            1176 non-null   float64
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294 entries, 442 to 1229
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      294 non-null    int64
#  1   BusinessTravel           294 non-null    float64
#  2   DailyRate                294 non-null    int64
#  3   Department               294 non-null    float64
#  4   DistanceFromHome         294 non-null    int64
#  5   Education                294 non-null    int64
#  6   EducationField           294 non-null    float64
#  7   Gender                   294 non-null    float64
#  8   HourlyRate               294 non-null    int64
#  9   JobInvolvement           294 non-null    int64
#  10  JobLevel                 294 non-null    int64
#  11  JobRole                  294 non-null    float64
#  12  JobSatisfaction          294 non-null    int64
#  13  MaritalStatus            294 non-null    float64
# ...

# %%
X_train.shape
# Out:
# (1176, 17)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=17)
X_train_trf = pca.fit_transform(X_train)
X_test_trf = pca.transform(X_test)
